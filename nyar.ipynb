# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
import pickle

# %%
dataset = pd.read_csv('Predict Students Dropout and Academic Success.csv', delimiter=';')
dataset
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
# dataset.drop(['Application mode', 'Application order', 'Previous qualification (grade)', 'Mothers qualification', 'Fathers qualification', 'Mothers occupation', 'Fathers occupation', 'International', 'Unemployment rate', 'Inflation rate', 'GDP'], axis=1, inplace=True)

# %%
missing = dataset.isnull().sum()
missing
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mothers qualification                             0
# Fathers qualification                             0
# Mothers occupation                                0
# Fathers occupation                                0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
dataset.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mothers qualification                               int64
# Fathers qualification                               int64
# Mothers occupation                                  int64
# Fathers occupation                                  int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

laen = LabelEncoder()
dataset['Target'] = laen.fit_transform(dataset['Target'])

# %%
dataset = dataset.applymap(pd.to_numeric, errors='coerce')
dataset.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mothers qualification                               int64
# Fathers qualification                               int64
# Mothers occupation                                  int64
# Fathers occupation                                  int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# ...

# %%
# Menampilkan semua baris yang memiliki nilai NaN di kolom manapun
nan_rows = dataset[dataset.isna().any(axis=1)]
print(nan_rows)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 1                  1                15                  1    9254
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# 5                  2                39                  1    9991
# 8                  1                 1                  3    9238
# ...              ...               ...                ...     ...
# 4415               4                39                  1    9500
# 4417               1                 1                  1    9070
# 4418               1                44                  1    9070
# 4419               1                 1                  6    9773
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 1                              1                       1
# ...

# %%
dataset = dataset.apply(lambda x: x.fillna(x.mean()) if x.dtype.kind in 'biufc' else x)

# %%
# # Konversi tipe data kolom ke numerik (misalnya integer)
# kolom_untuk_dikonversi = ['Admission grade', 'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (grade)']
# dataset[kolom_untuk_dikonversi] = dataset[kolom_untuk_dikonversi].astype(int)

# %%
for column in dataset.columns:
    plt.figure(figsize=(5,3))
    sns.boxplot(dataset[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
plt.figure(figsize=(130,20))
sns.boxplot(data=dataset)

plt.show()

# %%
def outliers(column_name):
    Q1 = dataset[column_name].quantile(0.25)
    Q3 = dataset[column_name].quantile(0.75)

    IQR = Q3-Q1

    lowwer = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR

    # isian = dataset[column_name].interpolate()
    # dataset.loc[(dataset[column_name] < lowwer) | (dataset[column_name] > upper), column_name] = isian
    
    outliers_lower = dataset[column_name] < lowwer
    outliers_upper = dataset[column_name] > upper
    dataset.loc[outliers_lower, column_name] = lowwer
    dataset.loc[outliers_upper, column_name] = upper
    
    sns.boxplot(y=column_name, data=dataset)

    return dataset

# %%
outliers('Marital status')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  1                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
outliers('Course')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5  8378.5
# 1                  1                15                  1  9254.0
# 2                  1                 1                  5  9070.0
# 3                  1                17                  2  9773.0
# 4                  1                39                  1  8378.5
# ...              ...               ...                ...     ...
# 4419               1                 1                  6  9773.0
# 4420               1                 1                  2  9773.0
# 4421               1                 1                  1  9500.0
# 4422               1                 1                  1  9147.0
# 4423               1                10                  1  9773.0
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
outliers('Daytime/evening attendance')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5  8378.5
# 1                  1                15                  1  9254.0
# 2                  1                 1                  5  9070.0
# 3                  1                17                  2  9773.0
# 4                  1                39                  1  8378.5
# ...              ...               ...                ...     ...
# 4419               1                 1                  6  9773.0
# 4420               1                 1                  2  9773.0
# 4421               1                 1                  1  9500.0
# 4422               1                 1                  1  9147.0
# 4423               1                10                  1  9773.0
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
outliers('Curricular units 2nd sem (enrolled)')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5  8378.5
# 1                  1                15                  1  9254.0
# 2                  1                 1                  5  9070.0
# 3                  1                17                  2  9773.0
# 4                  1                39                  1  8378.5
# ...              ...               ...                ...     ...
# 4419               1                 1                  6  9773.0
# 4420               1                 1                  2  9773.0
# 4421               1                 1                  1  9500.0
# 4422               1                 1                  1  9147.0
# 4423               1                10                  1  9773.0
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
outliers('Curricular units 2nd sem (evaluations)')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5  8378.5
# 1                  1                15                  1  9254.0
# 2                  1                 1                  5  9070.0
# 3                  1                17                  2  9773.0
# 4                  1                39                  1  8378.5
# ...              ...               ...                ...     ...
# 4419               1                 1                  6  9773.0
# 4420               1                 1                  2  9773.0
# 4421               1                 1                  1  9500.0
# 4422               1                 1                  1  9147.0
# 4423               1                10                  1  9773.0
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
outliers('Curricular units 2nd sem (approved)')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5  8378.5
# 1                  1                15                  1  9254.0
# 2                  1                 1                  5  9070.0
# 3                  1                17                  2  9773.0
# 4                  1                39                  1  8378.5
# ...              ...               ...                ...     ...
# 4419               1                 1                  6  9773.0
# 4420               1                 1                  2  9773.0
# 4421               1                 1                  1  9500.0
# 4422               1                 1                  1  9147.0
# 4423               1                10                  1  9773.0
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
outliers('Curricular units 2nd sem (grade)')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5  8378.5
# 1                  1                15                  1  9254.0
# 2                  1                 1                  5  9070.0
# 3                  1                17                  2  9773.0
# 4                  1                39                  1  8378.5
# ...              ...               ...                ...     ...
# 4419               1                 1                  6  9773.0
# 4420               1                 1                  2  9773.0
# 4421               1                 1                  1  9500.0
# 4422               1                 1                  1  9147.0
# 4423               1                10                  1  9773.0
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
outliers('Curricular units 2nd sem (without evaluations)')
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5  8378.5
# 1                  1                15                  1  9254.0
# 2                  1                 1                  5  9070.0
# 3                  1                17                  2  9773.0
# 4                  1                39                  1  8378.5
# ...              ...               ...                ...     ...
# 4419               1                 1                  6  9773.0
# 4420               1                 1                  2  9773.0
# 4421               1                 1                  1  9500.0
# 4422               1                 1                  1  9147.0
# 4423               1                10                  1  9773.0
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
sns.boxplot(data=dataset)
# Out:
# <Axes: >

# %%
x = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1].values

print(x)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5  8378.5
# 1                  1                15                  1  9254.0
# 2                  1                 1                  5  9070.0
# 3                  1                17                  2  9773.0
# 4                  1                39                  1  8378.5
# ...              ...               ...                ...     ...
# 4419               1                 1                  6  9773.0
# 4420               1                 1                  2  9773.0
# 4421               1                 1                  1  9500.0
# 4422               1                 1                  1  9147.0
# 4423               1                10                  1  9773.0
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
print(y)
# Out:
# [0 2 0 ... 0 2 2]

# %%
# Split data menjadi data pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Feature scaling
scaler = StandardScaler()  # Normalisasi fitur
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the model
gbm = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gbm.fit(X_train, y_train)

# Predict
y_pred = gbm.predict(X_test)

# Cek akurasi
accuracy = accuracy_score(y_test, y_pred)
print(f'Akurasi model: {accuracy * 100:.2f}%')

# Hitung confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix menggunakan seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Akurasi model: 74.01%

# %%
with open('gbm_model.pkl', 'wb') as model_file:
    pickle.dump(gbm, model_file)

with open('scaler.pkl', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)
